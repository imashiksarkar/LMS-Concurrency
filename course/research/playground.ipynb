// %%
const course = new Map<string, any>()

// %%
const newCourse = course.set('1', {
  id: '1',
  title: 'React',
  content: 'React is a JavaScript library for building user interfaces.',
  price: 100,
  seats: 10,
  instructorId: '1',
  version: 1,
  updatedAt: new Date(),
  createdAt: new Date(),
})

// %%
newCourse.get('1')
// Out:
// {
//   id: "1",
//   title: "React",
//   content: "React is a JavaScript library for building user interfaces.",
//   price: 100,
//   seats: 10,
//   instructorId: "1",
//   version: 1,
//   updatedAt: 2025-12-10T23:04:07.285Z,
//   createdAt: 2025-12-10T23:04:07.285Z
// }
